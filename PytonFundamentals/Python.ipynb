# %% [markdown]
# # **Python 100.1**

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ## Matematiksel islemler

# %%
   
1+1
# Out:
# 2

# %%
2*3
# Out:
# 6

# %%
4/7
# Out:
# 0.5714285714285714

# %%
84- 25
# Out:
# 59

# %%
2**4   #2 hoch 4
3**3   #3 hoch 3
# Out:
# 27

# %%
4%2  # Modulo Operator, Rest der Division von 4 durch 2  kalani verir
87%14
# Out:
# 3

# %%
20/7 # normal bölme işlemi, sonucu float verir
# Out:
# 2.857142857142857

# %%
15//7 # bölümdeki virgül öncesi tam sayiyi verir
20//7
# Out:
# 2

# %%
8/2*(2+2) #önce Parantez içindeki işlemi yapar, sonra soldan saga  bölme ve çarpma işlemlerini sırayla yapar
# Out:
# 16.0

# %% [markdown]
# ___

# %% [markdown]
# ---

# %% [markdown]
# ## Degisken atama

# %%
x = 2 
y = 3
z = x + y

# %%
z
# Out:
# 5

# %%
a = "domates"
b ="Salatalik"

# %%
a
# Out:
# 'domates'

# %%
b
# Out:
# 'Salatalik'

# %%
a+b
# Out:
# 'domatesSalatalik'

# %%
a + b ,"Sebzeler" ,"Meyveler"  # , ile birden fazla stringi ve int birleştirebiliriz.
# Out:
# ('domatesSalatalik', 'Sebzeler', 'Meyveler')

# %% [markdown]
# ___

# %% [markdown]
# ## Print

# %%
x = "Merhaba"

# %%
x
# Out:
# 'Merhaba'

# %%
print(x)
# Out:
# Merhaba

# %%
k = "patatesli"
l = "patlican"
m = "oturtma"

# %%
print (k+l+m)
# Out:
# patateslipatlicanoturtma

# %%
song ="Na "

# %%
print(song *8 , "Batman")
# Out:
# Na Na Na Na Na Na Na Na  Batman

# %%
marka = "Mercedes - Benz "
model= "W140"
Baujahr = 1995

# %%
print("{ma},{mo} , {bj}".format(ma=marka, mo=model, bj=Baujahr))
# Out:
# Mercedes - Benz ,W140 , 1995

# %%
print(f"{marka} {model} {Baujahr} tank gibi arabadir")
# Out:
# Mercedes - Benz  W140 1995 tank gibi arabadir

# %% [markdown]
# ___

# %% [markdown]
# ___

# %% [markdown]
# # Python Veri Türleri

# %% [markdown]
# ### List

# %%
[1, 2, 3]
# Out:
# [1, 2, 3]

# %%
["Merhaba",1,2,3,[4,5],6,[7,8]]
# Out:
# ['Merhaba', 1, 2, 3, [4, 5], 6, [7, 8]]

# %%
list_1= ["Mercedes Benz", "BMW", "Audi", "Volkswagen"]
list_1[0]  # Listenin ilk elemanina erisiriz, index 0 dan bas
# Out:
# 'Mercedes Benz'

# %%
list_1.append("Porsche")  # Listenin sonuna yeni bir eleman ekleriz
# apply end diziye yeni eleman ekler   Ctrl + K + U yorum satiri ekler
list_1
# Out:
# ['Mercedes Benz', 'BMW', 'Audi', 'Volkswagen', 'Porsche', 'Porsche']

# %%
list_1
